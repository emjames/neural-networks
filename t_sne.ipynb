# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/emjames/neural-networks/blob/master/t_sne.ipynb)

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1. Download the data
# Human Activity Recognition
# !mkdir data
# !wget http://groupware.les.inf.puc-rio.br/static/har/dataset-har-PUC-Rio-ugulino.zip
# !unzip dataset-har-PUC-Rio-ugulino.zip -d data
# Out:
# --2018-08-01 15:37:27--  http://groupware.les.inf.puc-rio.br/static/har/dataset-har-PUC-Rio-ugulino.zip
# Resolving groupware.les.inf.puc-rio.br (groupware.les.inf.puc-rio.br)... 139.82.71.134
# Connecting to groupware.les.inf.puc-rio.br (groupware.les.inf.puc-rio.br)|139.82.71.134|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2021733 (1.9M) [application/zip]
# Saving to: ‘dataset-har-PUC-Rio-ugulino.zip’
#
# dataset-har-PUC-Rio 100%[===================>]   1.93M   316KB/s    in 7.8s
#
# 2018-08-01 15:37:35 (255 KB/s) - ‘dataset-har-PUC-Rio-ugulino.zip’ saved [2021733/2021733]
#
# Archive:  dataset-har-PUC-Rio-ugulino.zip
#   inflating: data/dataset-har-PUC-Rio-ugulino.csv

# %%
df_dtypes = {'user': np.object, 'gender': np.object, 'age': np.int64, 'how_tall_in_meters': np.float64, 'weight': np.int64, 'body_mass_index': np.float64, 'x1': np.int64, 'y1': np.int64, 'z1': np.int64, 'x2': np.int64, 'y2': np.int64, 'z2': np.int64, 'x3': np.int64, 'y3': np.int64, 'z3': np.int64, 'x4': np.int64, 'y4': np.int64, 'z4': np.object, 'class': np.object}
# The decimal in the original data is a comma (',') so we must convert it to decimal
dataframe_all = pd.read_csv('data/dataset-har-PUC-Rio-ugulino.csv', sep=';', dtype=df_dtypes, decimal=',')
num_rows = dataframe_all.shape[0]

# %%
# 2. Clean the data
# count the number of missing elements in each column
counter_nan = dataframe_all.isnull().sum()
counter_no_nan = counter_nan[counter_nan == 0]

# remove columns with missing elements
dataframe_all = dataframe_all[counter_no_nan.keys()]
cols = dataframe_all.shape[1]
# leave x, y values only
dataframe_all = dataframe_all.iloc[:, 6:cols-1]

# %%
dataframe_all
# Out:
#         x1   y1   z1  x2   y2   z2   x3   y3   z3   x4   y4    z4
# 0       -3   92  -63 -23   18  -19    5  104  -92 -150 -103  -147
# 1       -3   94  -64 -21   18  -18  -14  104  -90 -149 -104  -145
# 2       -1   97  -61 -12   20  -15  -13  104  -90 -151 -104  -144
# 3       -2   96  -57 -15   21  -16  -13  104  -89 -153 -103  -142
# 4       -1   96  -61 -13   20  -15  -13  104  -89 -153 -104  -143
# 5       -2   95  -62 -14   19  -16  -13  104  -89 -153 -104  -142
# 6        1  100  -62 -10   22  -12  -13  104  -90 -151 -104  -143
# 7       -1   97  -63 -13   20  -15  -12  104  -88 -151 -104  -142
# 8       -1   98  -63 -14   19  -17  -13  104  -90 -152 -103  -144
# 9        0   98  -61 -11   22  -13  -13  104  -90 -151 -104  -144
# 10      -1   95  -60 -13   19  -17  -13  105  -89 -150 -104  -144
# 11       3  100  -59 -10   22  -13  -13  104  -90 -150 -103  -144
# 12       0   96  -61 -14   20  -15  -12  105  -88 -149 -104  -145
# ...

# %%
# 3. Create feature vectors
from sklearn.preprocessing import StandardScaler
x = dataframe_all.iloc[:, :-1].values
std_scalar = StandardScaler()
x_std = std_scalar.fit_transform(x)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# t-Distributed Stochastic Neighbor Embedding
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
x_test_2d = tsne.fit_transform(x_std)
markers = ('s', 'd', 'o', '^', 'v')
color_map = {0: 'red', 1: 'blue', 2: 'green', 3: 'purple', 4: 'cyan'}
plt.figure()

for idx, cl in enumarate(np.unique(x_test_2d)):
  plt.scatter(x=x_test_2d[cl, 0], y=x_test2d[cl, 1], c=color_map[idx], marker=markers[idx], label=cl)
plt.show()
